# %% [raw]
# ---
# title: "Project proposal"
# format:
#   html:
#     toc: true
#     toc-title: Contents
#     code-fold: show
#     self-contained: true
# jupyter: python3
# ---

# %% [markdown]
# ## Instructions {-}
#
# 1. Please answer the following questions as part of your project proposal.
#
# 2. Write your answers in the *Markdown* cells of the Jupyter notebook. You don't need to write any code, but if you want to, you may use the *Code* cells.
#
# 3. Use [Quarto](https://quarto.org/docs/output-formats/html-basics.html) to print the *.ipynb* file as HTML. You will need to open the command prompt, navigate to the directory containing the file, and use the command: `quarto render filename.ipynb --to html`. Submit the HTML file.
#
# 4. The project proposal is worth 1 point1, and is due on **14th Nov 2025 at 11:59 pm**.
#
# 5. You must make one submission as a group, and not individually.
#
# 6. Maintaining a GitHub repository is optional, though encouraged for the project.
#
# 7. Share the link of your project’s GitHub repository on the [spreadsheet](https://docs.google.com/spreadsheets/d/1C_H3bDKBAQnUJfbUzNrT0tus-96P-tEN/edit?usp=sharing&ouid=102488148453078668645&rtpof=true&sd=true).

# %% [markdown]
# # 1) Team name
# Mention your team name.
#
# *(0 points)*

# %% [markdown]
# **(JAG) Jenna, Grace + Alexa Final Project**

# %% [markdown]
# # 2) Member names
# Mention the names of your team members.
#
# *(0 points)*

# %% [markdown]
# **Grace Gormley, Jenna Krinsky, Alexa Pryor**

# %% [markdown]
# # 3) EDA (Exploratory data analysis) questions
#
# Explain the questions to be answered in your course project, one for each team member. Mention the name of the team member and the question that they will answer against it.
#
# *(0.4 points)*

# %% [markdown]
# **Grace: I want to compare the population, traffic congestion on roads due to cars, and the availability of CTA transit options in an area and discover where divvys are more popular to find what they serve as an alternative form of transit to, and also which areas in Chicago fit the market for Divvys but do not have them yet.**
#
#
# **Alexa: To what extent do Divvy micromobility usage patterns vary across Chicago neighborhoods, and how are these patterns associated with racial/ethnic demographics, socioeconomic conditions, built-environment characteristics, and phases of the Divvy system’s expansion?**
#
#
# **Jenna: How do socioeconomic and racial characteristics of Chicago neighborhoods predict Divvy ridership levels over time?**

# %% [markdown]
# # 4) Data
#
# What data sources will you use, please share the link of the data, and how will the data help answer the questions? Explain.
#
# If you are using multiple datasets, please provide the information for each dataset.
#
#
# *(0.4 points)*

# %% [markdown]
# **Grace: On top of the given divvy data, I want to use traffic data [https://data.cityofchicago.org/Transportation/Chicago-Traffic-Tracker-Congestion-Estimates-by-Se/n4j6-wkkf/about_data], CTA ridership (for popularity of CTA in region)[https://data.cityofchicago.org/Transportation/CTA-Ridership-Daily-Boarding-Totals/6iiy-9s97/about_data], CTA bus stops [https://data.cityofchicago.org/Transportation/CTA-Bus-Stops/hvnx-qtky], L stops [https://data.cityofchicago.org/Transportation/CTA-System-Information-List-of-L-Stops/8pix-ypme/about_data] and population data [https://data.cityofchicago.org/Community-Economic-Development/ACS-5-Year-Data-by-Ward/awnk-6fvc/about_data].**
#
#
# **Alexa:**
#
# **- Divvy's trip data for public use: Divvy trip data (https://divvybikes.com/system-data: Understand how, where, and when bikes are used)**
#
# **-Census Data: Demographic and socio-economic data (https://data.census.gov/: Link ridership to racial equity & community conditions.)**
#
# **-Chicago Data Portal: A wide range of datasets related to various aspects of the city (https://data.cityofchicago.org/browse?limitTo=datasets&sortBy=most_accessed&pageSize=20&page=1: Understand how physical surroundings shape micromobility usage.)**
#
#
# **Jenna: [https://data.cityofchicago.org/Health-Human-Services/Selected-socioeconomic-indicators-by-neighborhood/i9hv-en6g/about_data] and [https://data.cityofchicago.org/Health-Human-Services/Selected-socioeconomic-indicators-by-neighborhood/i9hv-en6g/about_data]**

# %% [markdown]
# # 5) Stakeholder

# %% [markdown]
# how will your project benefit the stakeholder? Explain.
#
# *(0.1 points)*

# %% [markdown]
# **Grace: This will help identify who the divvy bike users are, and what the divvy bikes are an alternative to, in terms of other travel. Finding wards/neighborhoods which match the conditions but don't already have many bikes will also help tell stakeholders where to look in the future.**
#
#
# **Alexa: providing a digestible summary of the association between ridership and demographics to get a better understanding of target audience for marketing.**
#
# Jenna: **Communicates insights on where bikes are needed and by whom, which can be used to improve physical mobility options.**
