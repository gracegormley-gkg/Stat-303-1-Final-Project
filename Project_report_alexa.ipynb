# %% [raw]
# ---
# title: "Project Report"
# subtitle: Team name
# author: Author 1, Author 2, Author 3, and Author 4
# date: 12/xx/2025
# number-sections: true
# abstract: _The ABSTRACT is to be in fully-justified italicized text at the top of the report, below the author information. The abstract section must summarise the four questions answered in the report, and the recommendations to the stakeholders based on the analysis. You may also briefly mention the results of the analysis that connect the questions to the recommendations. However, the abstract must not be more than 200 words in length_.
# format:
#   html:
#     toc: true
#     toc-title: Contents
#     code-fold: true
#     self-contained: true
#     font-size: 100%
#     toc-depth: 4
#     mainfont: serif
# jupyter: python3
# ---

# %% [markdown]
# ## Length of the report {-}
#
# The main report must be **no more than 15 pages** when printed as a PDF, **excluding** the cover page, AI disclosure, references, and appendix. There is **no minimum** page requirement. Reports that exceed 15 pages in the main body may be penalized for lack of conciseness.
#
#
# You may include additional materials in an **Appendix** (e.g., extra figures, tables, diagnostic plots, or detailed outputs). You are welcome to refer to the appendix in the main report to support your arguments. However, the appendix is **not guaranteed** to be read during grading and will only be consulted if the grader deems it necessary.
#
# **Delete this instructional section from your final report when using this template.**

# %% [markdown]
# ## Code should be put separately in the code template {-}
# Final reports should read like professional data science deliverables, written for a non-programmer audience. Do not include code in the report. We will review your code separately in the code template.
#
# **Delete this section from the report, when using this template.**

# %% [markdown]
# ## Problem statement
#
# Describe your four questions. Articulate your questions using absolutely no jargon.

# %% [markdown]
# Question: How does the use of Divvy bikes ridership access compare to that of Transportation Network Provider (TNP) ridership?
# Explanation: This meant plotting the spread of tnp and divvy stations and observing economical gaps in the placement of divvy stations.

# %% [markdown]
# ## Data sources
# What data did you use? Provide details about your data. Include links to data if you are using open-access data.

# %% [markdown]
# https://data.cityofchicago.org/Facilities-Geographic-Boundaries/Boundaries-Community-Areas-Map/cauq-8yn6 - Chicago neighborhood boundaries
# https://divvybikes.com/system-data - for divvy ride numbers/data
# https://data.cityofchicago.org/Transportation/Transportation-Network-Providers-Trips-2023-2024-/n26f-ihde/about_data - TNP ride numbers/data
# https://geodacenter.github.io/data-and-lab/Chi-CCA/ - population & choropleth data, transit type data

# %% [markdown]
# ## Data quality check / cleaning / preparation
#
# In a tabular form, show the distribution of values of each variable used in the analysis - for both categorical and continuous variables. Distribution of a categorical variable must include the number of missing values, the number of unique values, the frequency of all its levels. If a categorical variable has too many levels, you may just include the counts of the top 3-5 levels.
#
# Were there any potentially incorrect values of variables that required cleaning? If yes, how did you clean them?
#
# Did your analysis require any other kind of data preparation before it was ready to use?

# %% [markdown]
# These values weren't necessarily incorrect, but I filtered out tnp trips that left chicago - these were trips with a missing dropoff community area.
# In order to make correlation-based visualizations, I needed to aggregation my data and merge tnp and divvy data based on a certain time period.

# %% [markdown]
# ## Exploratory Data Analysis
#
# For each analysis:
#
# * What did you do exactly? How did you solve the problem? Why did you think it would be successful?
#
# * Mention any code repositories (with citations) or other sources that you used, and specifically what changes you made to them for your project.

# %% [markdown]
# The first step was to visualize how tnps and divvys are used. The heatmap and scatter plot show that divvvys abd tnps, at least for short trips, are used in similar ways.
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Further analysis also revealed that trips within Chicago tend to be short in general.
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# After that I visualized how widespread/available tnp and divvy use is in Chicago both tnp and divvy availability and use is concentrated in high income areas, however, tnp use is mroe widespread than divvy use and divvy use is more tied to where stations are placed.
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [raw]
# The third step was to Compare pricing. For shorter trips, divvys are cheaper than tnps, From here, we can identify demographic gaps in divvy and tnp use. Lower income areas have less divvy availability.
# The final step was to identify economical opportunities for divvy expansion. Since divvys have the edge on tnps in terms of cheaper pricing, divvy has more of an opportunity to expand into the south side/lower income areas.

# %% [markdown]
# ### Analysis 1
# *By \<Name of person doing the analysis>*
#
# ### Analysis 2
# *By \<Name of person doing the analysis>*
#
# ### Analysis 3
# *By \<Name of person doing the analysis>*
#
# ### Analysis 4
# *By \<Name of person doing the analysis>*

# %% [markdown]
# ## Discussion / Limitations (Optional)
#
# You are welcome to introduce additional sections or subsections, if required, to address your questions in detail. For example, you may briefly discuss potential future work that the research community could focus on to make further progress in the direction of your project's topic.

# %% [markdown]
# This EDA does not take into account frequency of tnp rides per capita or divvy rides per capity, which may help us understand popularity better. Also, the commuting data is sourced from surveys, which can contain volunteer and undercoverage bias.
# Potential future work may involve further investigating the need for bike transit in lower income regions of Chicago.
#
# Also, environmental layout may play a role. Divvy bikes are concentrated in the north/central regions, where people may be more inclined to ride bikes since it's more scenic and may have more tree canopy.
# These physical or aesthetic factors may influence where people choose to ride bikes more.
#
# One interesting topic of research would be to investigate whether beautification/environmental change (such as tree canopy, water bodies, and park spaces) increase bike ride frequency.
# Perhaps the city should invest more in better city planning on the south side.

# %% [markdown]
# ## Challenges and reflection
#
# Use this section to reflect honestly on your project process. This part is mainly for you and the instructors, not for the stakeholder.
#
# You might address:
#
# - **Anticipated vs. actual challenges.**
#   What problems did you expect at the beginning? What problems did you actually encounter (e.g., data quality, missing values, messy categories, time constraints, coordination within the team)?
#
# - **First attempts and revisions.**
#   Did the very first approach you tried work? If not, what went wrong? How did you debug, revise your questions, or improve your methods?
#
# - **Decisions and trade-offs.**
#   Did you simplify any questions, drop some analyses, or change your focus along the way? Why?
#
# - **What you learned.**
#   What are 2–3 key things you learned from doing this project (about data science, the Divvy data, or working in a team)? If you started over today, what would you do differently?
#
# Keep this section to about **1–2 paragraphs** or a short set of bullet points.

# %% [markdown]
# In our first approach, we worked more separately before coming together as a group. This helped us get a foundation for the throughline of our presentation. However, after meeting as a group, we found that there were a few
# inconsistencies as a result of working alone. After meeting as a group, our idea became much more clear and we we able to answer each of our questions in a mroe consistent way. In the end, we had an overarching question, and our change in
# focus or way of working as team helped us form a cohesive presentation.

# %% [markdown]
# ## Conclusions
#
# Do the individual analysis connect with each other to answer a bigger question? If yes, explain.

# %% [markdown]
# ## Recommendations to stakeholder(s)
#
# In this section:
#
# - Clearly state **which stakeholder** you are writing for (e.g., *Divvy operations manager*, *City of Chicago planner*, *marketing team*).
# - Provide **2–4 specific, actionable recommendations** based on your analysis. Be as concrete and practical as possible so stakeholders can use your suggestions directly.
# - Briefly discuss **limitations** of your analysis. Indicate whether stakeholders can act on your results as-is, or whether they should:
#   - collect more or updated data,
#   - perform additional analysis, or
#   - repeat your analysis on more recent data.

# %% [markdown]
# City of Chicago planner - Invest in more public spaces, greenery/tree canopy, parks, aesthetic water bodies (scenic beautification) overall on the southside.
# Divvy operations manager - Strategically place mroe divvy stations on the south side, as there seems to be a market for cheaper transit for short,quick trips where people are currently using tnps.

# %% [markdown]
# ## References {-}

# %% [markdown]
# List and number all bibliographical references. When referenced in the text, enclose the citation number in square brackets, for example [1].
#
# [1] Authors. The frobnicatable foo filter, 2014. Face and Gesture submission ID 324. Supplied as additional material
# fg324.pdf. 3

# %% [markdown]
# ## AI Tools and Assistance (Disclosure — for course purposes) {-}
#
# In this section, briefly describe **if and how** you used any AI tools while working on this project. This includes, for example, tools such as *ChatGPT*, *GitHub Copilot*, *Grammarly*, or other code-writing, code-completion, or writing-assistance tools.
#
# Please address:
#
# - **Which tools (if any)** you used.
# - **What you used them for** (e.g., brainstorming ideas, clarifying concepts, debugging code, editing writing, generating plots, etc.).
# - **What parts of the work are fully your own**, and how you checked or modified any AI-generated suggestions.
#
# If you did **not** use any AI tools, simply write:
#
# > We did not use any AI tools for this project.

# %% [markdown]
# I used chat gpt for comment descriptions as well as data aggregation.

# %% [markdown]
# ## Appendix {-}

# %% [markdown]
# You may put additional stuff here as Appendix. You may refer to the Appendix in the main report to support your arguments. However, the appendix section is unlikely to be checked while grading, unless the grader deems it necessary.
